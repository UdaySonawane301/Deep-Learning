# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df
# Out:
#           x1        x2  y
# 0  -2.509198 -9.371416  0
# 1   9.014286  2.728208  1
# 2   4.639879 -3.712880  0
# 3   1.973170  0.171414  1
# 4  -6.879627  8.151329  1
# ..       ...       ... ..
# 95 -0.124088 -3.015809  0
# 96  0.454657  4.519114  1
# 97 -1.449180  7.942205  1
# 98 -9.491617  7.741728  1
# 99 -7.842171  5.597511  1
#
# [100 rows x 3 columns]

# %%
x = df[['x1','x2']].values
y =df['y'].values

# %%
plt.figure(figsize=(10,6))
plt.scatter(x[:,0],x[:,1],c=y,cmap='winter',s=100)

# %%
def step(z):
    return 1 if z > 0 else 1

# %%
def perceptron(x, y):
    x = np.insert(x, 0, 1, axis=1)  # Add bias column
    weights = np.ones(x.shape[1])  # Initialize weights
    lr = 0.1

    for i in range(1000):
        j = np.random.randint(0, len(x))  # Choose valid random index
        y_hat = step(np.dot(x[j], weights))
        weights = weights + lr * (y[j] - y_hat) * x[j]

    return weights[0], weights[1:]

# %%
intercept_, coef_ = perceptron(x, y)
print("Intercept:", intercept_)
print("Coefficients:", coef_)
# Out:
# Intercept: -48.900000000000425
# Coefficients: [120.50282535 213.97873702]

# %%
m=-(coef_[0]/coef_[1])
n=-(intercept_/coef_[1])

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input+n

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(x[:,0],x[:,1],c=y,cmap='winter' ,s=100)

plt.title('Perceptron Decision Boundary')
plt.xlabel('SOFT SKILLS')
plt.ylabel('CGPA')
plt.grid(True)
plt.show()
